# %%
import os
import cv2
import numpy as np


images = []
labels = []

path = 'assets/data/training_data'

dir_list = os.listdir(path)
for i in dir_list:
  dir = os.path.join(path, i)
  file_list = os.listdir(dir)
  for j in file_list:
    files = os.path.join(dir, j)
    img = cv2.imread(files)
    img = cv2.resize(img, (64,64))
    img = np.array(img, dtype=np.float32)
    img = img/255
    images.append(img)
    labels.append(i)

# %%
X = np.array(images)
len(X)
# Out:
# 20628

# %%
X.shape
# Out:
# (20628, 64, 64, 3)

# %%
y = np.array(labels)
len(y)
# Out:
# 20628

# %%
y.shape
# Out:
# (20628,)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.utils import shuffle
X_sh, y_sh = shuffle(X, y, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
# Out:
# WARNING:tensorflow:From c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))  # Input shape is (64, 64, 1) for grayscale images
model.add(MaxPooling2D())
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=36, activation='softmax'))

# %%
# from keras.layers import TimeDistributed, LSTM

# model = Sequential()
# model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))
# model.add(MaxPooling2D())
# model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D())
# model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D())
# model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
# model.add(TimeDistributed(Flatten()))  # Add TimeDistributed wrapper for Flatten layer
# model.add(TimeDistributed(Dense(units=128, activation='relu')))
# model.add(TimeDistributed(Dense(units=64, activation='relu')))
# model.add(LSTM(units=10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_sh, y_sh ,validation_split=0.2, batch_size=25, epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\Users\ACER\OneDrive\Documents\Leon Folder\cobacoba\ocr.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ACER/OneDrive/Documents/Leon%20Folder/cobacoba/ocr.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> history = model.fit(X_sh, y_sh ,validation_split=0.2, batch_size=25, epochs=10)
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])

# %%
test_images = []
test_labels = []

path = 'assets/data/testing_data'

dir_list = os.listdir(path)
for i in dir_list:
  dir = os.path.join(path, i)
  file_list = os.listdir(dir)
  for j in file_list:
    files = os.path.join(dir, j)
    img = cv2.imread(files)
    img = cv2.resize(img, (64,64))
    img = np.array(img, dtype=np.float32)
    img = img/255
    test_images.append(img)
    test_labels.append(i)

# %%
X_test = np.array(test_images)
y_test = np.array(test_labels)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_test = le.fit_transform(y_test)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0507 - accuracy: 0.9742

# %%
print(test_loss,test_accuracy )
# Out:
# 0.050688162446022034 0.9742063283920288

# %%
model.save('ocr_model_2.h5')
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming you have loaded your labels into the 'labels' variable
le = LabelEncoder()
encoded_labels = le.fit_transform(labels)

# %%
np.save('label_encoder_classes.npy', le.classes_)
